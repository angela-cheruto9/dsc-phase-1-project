# %% [markdown]
# # Final Project Submission
#
# Please fill out:
# * Student name: Angela Cheruto
# * Student pace: full time
# * Scheduled project review date/time:
# * Instructor name: Mark/Antonny/Terry
# * Blog post URL:

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## 1. Loading data

# %%
#loading the data from title.basics file into excel

read_file = pd.read_csv (r'C:\Users\ADMIN\AppData\Local\Temp\AweZip\Temp1\AweZip1\title.basics.csv')
read_file.to_excel (r'C:\Users\ADMIN\Desktop\title.basics.xlsx', index = None, header=True)

# %%
# read data in the title.basics file

title_basics = pd.read_excel (r'C:\Users\ADMIN\Desktop\title.basics.xlsx')

title_basics
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
#loading the data from bom.movie_gross file 

read_file = pd.read_csv (r'C:\Users\ADMIN\AppData\Local\Temp\AweZip\Temp1\AweZip0\bom.movie_gross.csv')
read_file.to_excel (r'C:\Users\ADMIN\Desktop\bom.movie_gross.xlsx', index = None, header=True)

# %%
# read data in the bom.movie_gross file
    
bom_movie_gross = pd.read_excel (r'C:\Users\ADMIN\Desktop\bom.movie_gross.xlsx')

bom_movie_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
#loading the data from title.ratings file

read_file = pd.read_csv (r'C:\Users\ADMIN\AppData\Local\Temp\AweZip\Temp1\AweZip3\title.ratings.csv')
read_file.to_excel (r'C:\Users\ADMIN\Desktop\title.ratings.xlsx', index = None, header=True)

# %%
# read data in the title.ratings file

title_ratings = pd.read_excel (r'C:\Users\ADMIN\Desktop\title.ratings.xlsx')

title_ratings.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
# joining the title_basics and title_ratings dataframes using the common column 'tconst'
title_basics_ratings = pd.merge(left= title_basics, right=title_ratings, how='left', left_on='tconst', right_on='tconst')
title_basics_ratings
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
# joining the title_basics_ratings and bom-movie_gross dataframes using the common column 'title' and 'original_title' respectively

df = pd.merge(left= bom_movie_gross, right=title_basics_ratings, how='left', left_on='title', right_on='original_title')
df
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3994                                    The Quake       Magn.          6200.0
# 3995                  Edward II (2018 re-release)          FM          4800.0
# 3996                                     El Pacto        Sony          2500.0
# 3997                                     The Swan  Synergetic          2400.0
# 3998                            An Actor Prepares       Grav.          1700.0
#
# ...

# %% [markdown]
# # 1.2 Inspecting the dataframe

# %%
# check the number of rows and columnns 
df.shape
# Out:
# (3999, 13)

# %%
# check the data and datatype of the title.basics
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3999 entries, 0 to 3998
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            3999 non-null   object
#  1   studio           3994 non-null   object
#  2   domestic_gross   3964 non-null   float64
#  3   foreign_gross    2431 non-null   object
#  4   year             3999 non-null   int64
#  5   tconst           2776 non-null   object
#  6   primary_title    2776 non-null   object
#  7   original_title   2776 non-null   object
#  8   start_year       2776 non-null   float64
#  9   runtime_minutes  2610 non-null   float64
#  10  genres           2740 non-null   object
#  11  averagerating    2447 non-null   float64
#  12  numvotes         2447 non-null   float64
# dtypes: float64(5), int64(1), object(7)
# memory usage: 437.4+ KB

# %%
# check the numerical data contained in title.basics
df.describe()
# Out:
#        domestic_gross         year   start_year  runtime_minutes  \
# count    3.964000e+03  3999.000000  2776.000000      2610.000000
# mean     2.882617e+07  2013.983996  2013.987032       104.136398
# std      6.564615e+07     2.477259     2.567400        25.652179
# min      1.000000e+02  2010.000000  2010.000000         2.000000
# 25%      1.260000e+05  2012.000000  2012.000000        92.000000
# 50%      1.600000e+06  2014.000000  2014.000000       103.000000
# 75%      2.980000e+07  2016.000000  2016.000000       117.000000
# max      9.367000e+08  2018.000000  2020.000000       623.000000
#
#        averagerating      numvotes
# count    2447.000000  2.447000e+03
# mean        6.406293  7.273033e+04
# std         1.045029  1.345874e+05
# min         1.600000  5.000000e+00
# 25%         5.800000  3.776000e+03
# 50%         6.500000  2.074600e+04
# 75%         7.100000  8.063900e+04
# max         9.200000  1.841066e+06

# %% [markdown]
# # 2.0 Data cleaning
#
#
# (Checking for null values,missing values,dropping unnecessary columns,rows and replacing values

# %% [markdown]
# ## 2.1 Checking for null values

# %%
# Show the number of null values in each column in the dataframe 
df.isnull().sum().sort_values(ascending =False)
# Out:
# foreign_gross      1568
# averagerating      1552
# numvotes           1552
# runtime_minutes    1389
# genres             1259
# tconst             1223
# primary_title      1223
# original_title     1223
# start_year         1223
# domestic_gross       35
# studio                5
# title                 0
# year                  0
# dtype: int64

# %%
# number of null values in each row 
df.isnull().sum(axis=1).sort_values(ascending =False)
# Out:
# 3521    9
# 1182    9
# 3124    9
# 1964    9
# 3125    9
#        ..
# 1750    0
# 1749    0
# 1748    0
# 1746    0
# 1999    0
# Length: 3999, dtype: int64

# %%
# percentage of null values in each row 
title_basics.isnull().sum(axis=1).sort_values(ascending =False)/len(title_basics)*100
# Out:
# 108971    0.002053
# 104418    0.002053
# 111899    0.002053
# 116205    0.002053
# 82058     0.002053
#             ...
# 53353     0.000000
# 53352     0.000000
# 53351     0.000000
# 53350     0.000000
# 73072     0.000000
# Length: 146144, dtype: float64

# %% [markdown]
# ## 2.2 Dropping columns and rows

# %%
# drop unnecessary columns
df= df.drop(columns=['primary_title','tconst'])
df
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3994                                    The Quake       Magn.          6200.0
# 3995                  Edward II (2018 re-release)          FM          4800.0
# 3996                                     El Pacto        Sony          2500.0
# 3997                                     The Swan  Synergetic          2400.0
# 3998                            An Actor Prepares       Grav.          1700.0
#
# ...

# %%
#check the sum of null values in each column of the dataframe after dropping the two columns
df.isnull().sum()
# Out:
# title                 0
# studio                5
# domestic_gross       35
# foreign_gross      1568
# year                  0
# original_title     1223
# start_year         1223
# runtime_minutes    1389
# genres             1259
# averagerating      1552
# numvotes           1552
# dtype: int64

# %%
#check the sum of null values in each column of the dataframe after dropping the two columns
df.isnull().sum()
# Out:
# title                 0
# studio                5
# domestic_gross       35
# foreign_gross      1568
# year                  0
# original_title     1223
# start_year         1223
# runtime_minutes    1389
# genres             1259
# averagerating      1552
# numvotes           1552
# dtype: int64

# %%
df.dropna(inplace=True)
df
# Out:
#                                         title      studio  domestic_gross  \
# 0                                 Toy Story 3          BV     415000000.0
# 3                                   Inception          WB     292600000.0
# 4                         Shrek Forever After        P/DW     238700000.0
# 5                  The Twilight Saga: Eclipse        Sum.     300500000.0
# 6                                  Iron Man 2        Par.     312400000.0
# ...                                       ...         ...             ...
# 3863               Bilal: A New Breed of Hero          VE        491000.0
# 3867                          I Still See You         LGF          1400.0
# 3879                    The Catcher Was a Spy         IFC        725000.0
# 3909                               Time Freak  Grindstone         10000.0
# 3961  Antonio Lopez 1970: Sex Fashion & Disco          FM         43200.0
#
#      foreign_gross  year                           original_title  start_year  \
# ...

# %% [markdown]
# ## 3.0 Data cleaning on gross data

# %%
# divide the domestic_gross to make the values easier to work with
domestic_gross = df['domestic_gross'].floordiv(1000000)
domestic_gross
# Out:
# 0       415.0
# 3       292.0
# 4       238.0
# 5       300.0
# 6       312.0
#         ...
# 3863      0.0
# 3867      0.0
# 3879      0.0
# 3909      0.0
# 3961      0.0
# Name: domestic_gross, Length: 1517, dtype: float64

# %%
# check the datatype in foreign_gross
df['foreign_gross'].dtypes
# Out:
# dtype('O')

# %%
# divide the gross column by 1000000 to make the values easier to work with
df.foreign_gross=int(float())
df.foreign_gross= df['foreign_gross'].astype(str).astype(int)
print(df.foreign_gross.dtypes)
# Out:
# int32

# %%
# divide the gross column by 1000000 to make the numbers easier to work with
foreign_gross = df['foreign_gross'].floordiv(1000000)
foreign_gross
# Out:
# 0       0
# 3       0
# 4       0
# 5       0
# 6       0
#        ..
# 3863    0
# 3867    0
# 3879    0
# 3909    0
# 3961    0
# Name: foreign_gross, Length: 1517, dtype: int32

# %%
# Create a new column to hold values for total_gross
df["total_gross"] = df.foreign_gross + df.domestic_gross
df["total_gross"]
# Out:
# 0       415000000.0
# 3       292600000.0
# 4       238700000.0
# 5       300500000.0
# 6       312400000.0
#            ...
# 3863       491000.0
# 3867         1400.0
# 3879       725000.0
# 3909        10000.0
# 3961        43200.0
# Name: total_gross, Length: 1517, dtype: float64

# %%
# arrange the total gross in descending order
total_gross = df.sort_values("total_gross",ascending = False)
total_gross.head()
# Out:
#                        title studio  domestic_gross  foreign_gross  year  \
# 3638           Black Panther     BV     700100000.0              0  2018
# 3637  Avengers: Infinity War     BV     678800000.0              0  2018
# 2182          Jurassic World   Uni.     652300000.0              0  2015
# 3640           Incredibles 2     BV     608600000.0              0  2018
# 2735            Finding Dory     BV     486300000.0              0  2016
#
#               original_title  start_year  runtime_minutes  \
# 3638           Black Panther      2018.0            134.0
# 3637  Avengers: Infinity War      2018.0            149.0
# 2182          Jurassic World      2015.0            124.0
# 3640           Incredibles 2      2018.0            118.0
# 2735            Finding Dory      2016.0             97.0
#
#                           genres  averagerating  numvotes  total_gross
# 3638     Action,Adventure,Sci-Fi            7.3  516148.0  700100000.0
# ...

# %%
# A bar plot to show the total_gross amongst the studios
studio =  total_gross['studio'].head(100)
total_gross =  total_gross['total_gross'].head(100)
fig = plt.figure(figsize = (10, 5))
#  Bar plot
plt.bar(studio, total_gross, color ='green',
        width = 0.5)
plt.xlabel("Studio")
plt.ylabel("Total gross")
plt.xticks(rotation= 60,fontsize=10)
plt.title("Relationship between total gross and studio ")
plt.show();

# %%
'''
The studio vs total_gross graph is skewed to the left showing the studios that made the most revenue.The total_gross for the studios decreases as the graph progresses.
BV made the most total_gross from the graph above.
'''
# Out:
# '\nThe studio vs total_gross graph is skewed to the left showing the studios that made the most revenue.The total_gross for the studios decreases as the graph progresses.\nBV made the most total_gross from the graph above.\n'

# %%
# A bar plot to show the total gross made in the years
total_gross = df['total_gross']
year = df['year']
fig = plt.figure(figsize = (10, 5))
#  Bar plot
plt.bar(year,total_gross, color ='green',
        width = 0.5)
plt.xlabel("Year")
plt.ylabel("Total gross")
plt.title("Relationship between year and total gross")
plt.show();

# %%
'''
The bar chart above shows the relationship between the total_gross and the year the movies made the revenue.
The most revenue was made in the year 2018, and as the years go by  the total_gross seem to increase except for a few instances where it fluctuates
'''
# Out:
# '\nThe bar chart above shows the relationship between the total_gross and the year the movies made the revenue.\nThe most revenue was made in the year 2018, and as the years go by  the total_gross seem to increase except for a few instances where it fluctuates\n'

# %%
# mean of total gross in each genre
df.groupby(['genres']).total_gross.mean().sort_values(ascending=False).head(10)
# Out:
# genres
# Documentary,Drama,Sport    4.126000e+08
# Sci-Fi                     4.126000e+08
# Adventure,Drama,Sport      4.007000e+08
# Family                     3.565000e+08
# Comedy,Mystery             2.545000e+08
# Action,Adventure,Sci-Fi    2.310442e+08
# Adventure,Drama,Sci-Fi     2.082000e+08
# Adventure,Fantasy          1.929000e+08
# Biography,Drama,Musical    1.743000e+08
# Drama,Western              1.628000e+08
# Name: total_gross, dtype: float64

# %% [markdown]
# ## 3.1 Data analysis on runtime data

# %%
# find the mean runtime of the dataframe
df.runtime_minutes.mean()
# Out:
# 107.62491760052735

# %%
# movie with the shortest and longest runtime
runtime_df = df['runtime_minutes' ]
run_time = df['runtime_minutes']
print(df)
print("Longest runtime_minutes")
print(run_time.max())
print("Shortest runtime_minutes")
print(run_time.min())
# Out:
#                                         title      studio  domestic_gross  \
# 0                                 Toy Story 3          BV     415000000.0
# 3                                   Inception          WB     292600000.0
# 4                         Shrek Forever After        P/DW     238700000.0
# 5                  The Twilight Saga: Eclipse        Sum.     300500000.0
# 6                                  Iron Man 2        Par.     312400000.0
# ...                                       ...         ...             ...
# 3863               Bilal: A New Breed of Hero          VE        491000.0
# 3867                          I Still See You         LGF          1400.0
# 3879                    The Catcher Was a Spy         IFC        725000.0
# 3909                               Time Freak  Grindstone         10000.0
# 3961  Antonio Lopez 1970: Sex Fashion & Disco          FM         43200.0
#
#       foreign_gross  year                           original_title  \
# ...

# %%
# sort the run_time in descending order
run_time_order = df.sort_values('runtime_minutes', ascending=False)
run_time_order.head()
# Out:
#                              title studio  domestic_gross  foreign_gross  \
# 2888  M.S. Dhoni: The Untold Story    FIP       1800000.0              0
# 826                         Aurora   CGld          5700.0              0
# 1335       The Wolf of Wall Street   Par.     116900000.0              0
# 907                    Cloud Atlas     WB      27100000.0              0
# 2830                        Sultan   Yash       6200000.0              0
#
#       year                original_title  start_year  runtime_minutes  \
# 2888  2016  M.S. Dhoni: The Untold Story      2016.0            184.0
# 826   2011                        Aurora      2010.0            181.0
# 1335  2013       The Wolf of Wall Street      2013.0            180.0
# 907   2012                   Cloud Atlas      2012.0            172.0
# 2830  2016                        Sultan      2016.0            170.0
#
#                      genres  averagerating   numvotes  total_gross
# ...

# %%
# create a barchart to show the runtime vs genres
genres = df['genres'].head(10)
runtime = df['runtime_minutes'].head(10)
fig = plt.figure(figsize = (10,5))
#  Bar plot
plt.bar(genres,runtime , color ='green',
        width = 0.5)
plt.xlabel("Genres")
plt.ylabel("Runtime in minutes")
plt.xticks(rotation= 80,fontsize=10)
plt.title("Genres and runtime of movies ")
plt.show();

# %%
'''
Action,Adventure,Sci-Fi is the combination of genre which had the highest runtime_minutes
'''
# Out:
# '\nAction,Adventure,Sci-Fi is the combination of genre which had the highest runtime_minutes\n'

# %%
# Runtime histogram/density plot

# plot a histogram to show the distribution of genres in the dataframe
data= df['runtime_minutes']
plt.figure(figsize=(10,5))
plt.hist(data, bins=30, align='left', color='g', edgecolor='r',
              linewidth=1)
 
# Add axis labels
plt.xlabel("Runtime_minutes")
plt.xticks(rotation= 80,fontsize=10)
plt.ylabel("Frequency of runtime_minutes")
plt.title("Distribution of runtime_minutes")
 
plt.show()

# %%
'''
A high number of movies have a runtime of 100 minutes which is quite close to the mean which is 107 minutes
'''
# Out:
# '\nA high number of movies have a runtime of 100 minutes which is quite close to the mean which is 107 minutes\n'

# %%
# Plot a boxplot for runtime and averagerating
df.boxplot(column = 'runtime_minutes', by = 'averagerating')
plt.ylabel('runtime averagerating')
plt.title('runtime averagerating boxplot')
# Out:
# Text(0.5, 1.0, 'runtime averagerating boxplot')

# %% [markdown]
# ## 3.2 Data cleaning and cleaning on averagerating and numvotes

# %%
#Find the mean of the numvotes
df['numvotes'].mean()
# Out:
# 108713.3005932762

# %%
movie_ratings1 = df.groupby('year')['averagerating'].mean().sort_values(ascending=False).head(10)
movie_ratings1
# Out:
# year
# 2013    6.537838
# 2014    6.478481
# 2016    6.465385
# 2015    6.433918
# 2018    6.425352
# 2017    6.425325
# 2011    6.395261
# 2012    6.392571
# 2010    6.329208
# Name: averagerating, dtype: float64

# %%
# averagerating for the initial dataframe
movie_ratings2 = df.groupby('genres')['averagerating'].mean().sort_values(ascending=False).head(10)
movie_ratings2
# Out:
# genres
# Adventure                         9.2
# Action,Sport                      8.4
# Drama,Western                     8.4
# Adventure,Drama,Sci-Fi            8.3
# Crime,Documentary                 8.3
# Fantasy                           8.2
# Biography,Documentary,Thriller    8.1
# Comedy,Crime,Documentary          8.0
# Documentary,Family                7.8
# Animation,Biography,Crime         7.8
# Name: averagerating, dtype: float64

# %%
'''
Adventure had the highest rating in the dataframe with a 9.2
'''
# Out:
# '\nAdventure had the highest rating in the dataframe with a 9.2\n'

# %%
# check the value count for averagerating in the dataframe
df['averagerating'].value_counts().sort_values(ascending=False)
# Out:
# 6.2    75
# 6.3    75
# 6.6    72
# 6.5    67
# 6.8    65
#        ..
# 3.3     1
# 8.7     1
# 2.1     1
# 2.9     1
# 1.6     1
# Name: averagerating, Length: 64, dtype: int64

# %%
#check the value count for number of votes 
df['numvotes'].value_counts().sort_values(ascending=False)
# Out:
# 14.0      7
# 7.0       7
# 8.0       7
# 6.0       7
# 12.0      6
#          ..
# 5457.0    1
# 7418.0    1
# 9882.0    1
# 6372.0    1
# 3455.0    1
# Name: numvotes, Length: 1446, dtype: int64

# %%
# Sort by the 100 leading movies in reference to votes and averagerating
best_100_votes = df[df['numvotes']>109000].sort_values(by ='averagerating',ascending = False).head(100)
best_100_votes
# Out:
#                                title studio  domestic_gross  foreign_gross  \
# 3                          Inception     WB     292600000.0              0
# 1732                    Interstellar   Par.     188000000.0              0
# 3637          Avengers: Infinity War     BV     678800000.0              0
# 2762                          Dangal    UTV      12400000.0              0
# 1848                        Whiplash    SPC      13100000.0              0
# ...                              ...    ...             ...            ...
# 3290                     Baby Driver   TriS     107800000.0              0
# 397   Rise of the Planet of the Apes    Fox     176800000.0              0
# 2875              Hell or High Water    LGF      27000000.0              0
# 2744                           Moana     BV     248800000.0              0
# 3667                   A Quiet Place   Par.     188000000.0              0
#
# ...

# %%
best_100_votes['genres'].value_counts()
# Out:
# Action,Adventure,Sci-Fi       7
# Adventure,Animation,Comedy    7
# Action,Adventure,Comedy       6
# Biography,Drama,History       5
# Drama                         4
# Action,Crime,Drama            4
# Comedy,Drama,Romance          4
# Action,Adventure,Animation    4
# Drama,Mystery,Sci-Fi          3
# Crime,Drama,Mystery           3
# Biography,Drama               3
# Biography,Drama,Thriller      3
# Biography,Drama,Sport         2
# Adventure,Drama,Sci-Fi        2
# Drama,Romance                 2
# Drama,Thriller                2
# Crime,Drama                   2
# Biography,Comedy,Drama        2
# Action,Adventure,Thriller     2
# Adventure,Comedy,Drama        1
# Adventure,Fantasy             1
# Comedy,Drama,Fantasy          1
# Animation,Comedy,Family       1
# Action,Adventure,Drama        1
# Drama,Sci-Fi,Thriller         1
# Comedy,Fantasy,Romance        1
# Biography,Drama,Musical       1
# Action,Drama,History          1
# Action,Drama,Sci-Fi           1
# ...

# %%
# Scatter plot to show the correlation between averagerating and numvotes ot the best_100 movies
x = best_100_votes['averagerating']
y = best_100_votes['numvotes']

plt.scatter(x, y, c='b')
plt.title('scatter plot')
plt.xlabel('averagerating')
plt.ylabel('numvotes')
plt.show()

# %%
'''
There is a positive correlation between average rating and numvotes since the higher the rating the higher the number of votes.
'''
# Out:
# '\nThere is a positive correlation between average rating and numvotes since the higher the rating the higher the number of votes.\n'

# %%
# finding the average of rating and votes using the mean
df.insert(11,column='num_rate', value =df.loc[:,['numvotes','averagerating']].mean(axis=1))

# %%
df.sort_values(by ='num_rate',ascending = False , inplace=True )

# %%
# find movies with an absolute difference of over 0.5 between the numvotes and averagerating
Numvotes_rating_100 =df[abs(df['numvotes']-df['averagerating']<0.5)]

# find the top 100 movies
Numvotes_rating_100[(abs(df['numvotes']-df['averagerating'])<0.5)&(df['averagerating']>7)].sort_index()[0:5]
# Out:
# C:\Users\ADMIN\AppData\Local\Temp/ipykernel_18844/549205682.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   Numvotes_rating_100[(abs(df['numvotes']-df['averagerating'])<0.5)&(df['averagerating']>7)].sort_index()[0:5]
#             title studio  domestic_gross  foreign_gross  year original_title  \
# 45            Red   Sum.      90400000.0              0  2010            Red
# 56    Unstoppable    Fox      81600000.0              0  2010    Unstoppable
# 1160     Meerkats    NGE        778000.0              0  2012       Meerkats
# 1345     Oblivion   Uni.      89100000.0              0  2013       Oblivion
# 3430     Stronger  RAtt.       4200000.0              0  2017       Stronger
#
#       start_year  runtime_minutes        genres  averagerating  numvotes  \
# 45        2014.0            107.0         Drama            8.4       8.0
# 56        2019.0             84.0   Documentary            8.1       8.0
# ...

# %%
Numvotes_rating_100.sort_values(by='num_rate', ascending=False, inplace=True)
Numvotes_rating_100.reset_index(drop=True, inplace=True)
Numvotes_rating_100[0:5]
# Out:
# C:\Users\ADMIN\anaconda3\An4\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#          title studio  domestic_gross  foreign_gross  year original_title  \
# 0     The Wall  RAtt.       1800000.0              0  2017       The Wall
# 1          Red   Sum.      90400000.0              0  2010            Red
# 2     Stronger  RAtt.       4200000.0              0  2017       Stronger
# 3  Unstoppable    Fox      81600000.0              0  2010    Unstoppable
# 4     Oblivion   Uni.      89100000.0              0  2013       Oblivion
#
#    start_year  runtime_minutes        genres  averagerating  numvotes  \
# 0      2010.0             78.0   Documentary            9.2       8.0
# ...

# %%
# Scatter plot to show the correlation ofnthe absolute difference between averagerating and numvotes ot the best_100 movies
x = Numvotes_rating_100['averagerating']
y = Numvotes_rating_100['numvotes']

plt.scatter(x, y, c='b')
plt.title('scatter plot')
plt.xlabel('averagerating')
plt.ylabel('numvotes')
plt.show()

# %% [markdown]
# ## 3.3 Data analysis on genre

# %%
df_genre = df.assign(genres= df['genres'].str.split(","))
df_genre.head()
# Out:
#                         title studio  domestic_gross  foreign_gross  year  \
# 3                   Inception     WB     292600000.0              0  2010
# 849     The Dark Knight Rises     WB     448100000.0              0  2012
# 1732             Interstellar   Par.     188000000.0              0  2014
# 864          Django Unchained  Wein.     162800000.0              0  2012
# 1335  The Wolf of Wall Street   Par.     116900000.0              0  2013
#
#                original_title  start_year  runtime_minutes  \
# 3                   Inception      2010.0            148.0
# 849     The Dark Knight Rises      2012.0            164.0
# 1732             Interstellar      2014.0            169.0
# 864          Django Unchained      2012.0            165.0
# 1335  The Wolf of Wall Street      2013.0            180.0
#
#                            genres  averagerating   numvotes  num_rate  \
# 3     [Action, Adventure, Sci-Fi]            8.8  1841066.0  920537.4
# ...

# %%
df_genre = df_genre.explode('genres')
df_genre
# Out:
#                            title studio  domestic_gross  foreign_gross  year  \
# 3                      Inception     WB     292600000.0              0  2010
# 3                      Inception     WB     292600000.0              0  2010
# 3                      Inception     WB     292600000.0              0  2010
# 849        The Dark Knight Rises     WB     448100000.0              0  2012
# 849        The Dark Knight Rises     WB     448100000.0              0  2012
# ...                          ...    ...             ...            ...   ...
# 173                       Buried    LGF       1000000.0              0  2010
# 466                         Paul   Uni.      37400000.0              0  2011
# 1376                        Mama   Uni.      71600000.0              0  2013
# 396                          Rio    Fox     143600000.0              0  2011
# 2926  The Other Side of the Door    Fox       3000000.0              0  2016
#
# ...

# %%
# check the value count for averagerating in the dataframe
df_genres=df_genre['genres'].value_counts()
df_genres
# Out:
# Drama          766
# Comedy         525
# Action         396
# Adventure      330
# Thriller       261
# Crime          223
# Romance        211
# Biography      148
# Horror         147
# Mystery        124
# Sci-Fi         109
# Fantasy        108
# Animation       98
# Family          81
# Documentary     78
# History         60
# Music           44
# Sport           35
# War             14
# Western          9
# Musical          9
# News             1
# Name: genres, dtype: int64

# %%
# plot a histogram to show the distribution of genres in the dataframe
data= df_genre['genres']
plt.figure(figsize=(10,9))
plt.hist(data, bins=21, align='left', color='g', edgecolor='r',
              linewidth=1)
 
# Add axis labels
plt.xlabel("Genres")
plt.xticks(rotation= 80,fontsize=10)
plt.ylabel("Frequency of genres")
plt.title("Distribution of genres")
 
plt.show()

# %%
'''
The histogram shows that Drama is the most produced genre as it carries the most count

'''
# Out:
# '\nThe histogram shows that Drama is the most produced genre as it carries the most count\n\n'

# %% [markdown]
# ## 3.4 Data analysis on numvotes and averagerating on genre

# %%
best_100_genre = df[df['numvotes']>109000].sort_values(by ='averagerating',ascending = False).head(100)
best_100_genre
# Out:
#                        title studio  domestic_gross  foreign_gross  year  \
# 3                  Inception     WB     292600000.0              0  2010
# 1732            Interstellar   Par.     188000000.0              0  2014
# 2762                  Dangal    UTV      12400000.0              0  2016
# 1848                Whiplash    SPC      13100000.0              0  2014
# 3637  Avengers: Infinity War     BV     678800000.0              0  2018
# ...                      ...    ...             ...            ...   ...
# 82                  Kick-Ass    LGF      48100000.0              0  2010
# 2744                   Moana     BV     248800000.0              0  2016
# 2875      Hell or High Water    LGF      27000000.0              0  2016
# 3705           The Favourite   FoxS      34400000.0              0  2018
# 1415          The Book Thief    Fox      21500000.0              0  2013
#
#               original_title  start_year  runtime_minutes  \
# ...

# %%
best_100_genre  = best_100_genre.assign(genres= best_100_genre['genres'].str.split(","))
best_100_genre .head()
# Out:
#                        title studio  domestic_gross  foreign_gross  year  \
# 3                  Inception     WB     292600000.0              0  2010
# 1732            Interstellar   Par.     188000000.0              0  2014
# 2762                  Dangal    UTV      12400000.0              0  2016
# 1848                Whiplash    SPC      13100000.0              0  2014
# 3637  Avengers: Infinity War     BV     678800000.0              0  2018
#
#               original_title  start_year  runtime_minutes  \
# 3                  Inception      2010.0            148.0
# 1732            Interstellar      2014.0            169.0
# 2762                  Dangal      2016.0            161.0
# 1848                Whiplash      2014.0            106.0
# 3637  Avengers: Infinity War      2018.0            149.0
#
#                            genres  averagerating   numvotes   num_rate  \
# 3     [Action, Adventure, Sci-Fi]            8.8  1841066.0  920537.40
# ...

# %%
best_100_genre = best_100_genre.explode('genres')
best_100_genre
# Out:
#                title studio  domestic_gross  foreign_gross  year  \
# 3          Inception     WB     292600000.0              0  2010
# 3          Inception     WB     292600000.0              0  2010
# 3          Inception     WB     292600000.0              0  2010
# 1732    Interstellar   Par.     188000000.0              0  2014
# 1732    Interstellar   Par.     188000000.0              0  2014
# ...              ...    ...             ...            ...   ...
# 3705   The Favourite   FoxS      34400000.0              0  2018
# 3705   The Favourite   FoxS      34400000.0              0  2018
# 3705   The Favourite   FoxS      34400000.0              0  2018
# 1415  The Book Thief    Fox      21500000.0              0  2013
# 1415  The Book Thief    Fox      21500000.0              0  2013
#
#       original_title  start_year  runtime_minutes     genres  averagerating  \
# 3          Inception      2010.0            148.0     Action            8.8
# ...

# %%
best_100_genre.tail()
# Out:
#                title studio  domestic_gross  foreign_gross  year  \
# 3705   The Favourite   FoxS      34400000.0              0  2018
# 3705   The Favourite   FoxS      34400000.0              0  2018
# 3705   The Favourite   FoxS      34400000.0              0  2018
# 1415  The Book Thief    Fox      21500000.0              0  2013
# 1415  The Book Thief    Fox      21500000.0              0  2013
#
#       original_title  start_year  runtime_minutes     genres  averagerating  \
# 3705   The Favourite      2018.0            119.0  Biography            7.6
# 3705   The Favourite      2018.0            119.0      Drama            7.6
# 3705   The Favourite      2018.0            119.0    History            7.6
# 1415  The Book Thief      2013.0            131.0      Drama            7.6
# 1415  The Book Thief      2013.0            131.0        War            7.6
#
#       numvotes  num_rate  total_gross
# 3705  116011.0   58009.3   34400000.0
# 3705  116011.0   58009.3   34400000.0
# ...

# %%
# create a barchart to show genres vs numvotes
genres = df_genre['genres'].head(100)
numvotes = df['numvotes'].head(100)
fig = plt.figure(figsize = (12, 9))
#  Bar plot
plt.bar(genres,numvotes , color ='green',
        width = 0.5)
plt.xlabel("Genres")
plt.ylabel("Numvotes")
plt.xticks(rotation= 80,fontsize=10)
plt.title("Genres and numvotes ")
plt.show();

# %%
'''
Action has the most votes in the top movie selection.
'''
# Out:
# '\nAction has the most votes in the top movie selection.\n'

# %% [markdown]
# ## 3.5 Data analysis on genre and averagerating

# %%
# the ratings of the original dataframe
movie_ratings2 = df.groupby('genres')['averagerating'].mean().sort_values(ascending=False).head(10)
movie_ratings2
# Out:
# genres
# Adventure                         9.2
# Action,Sport                      8.4
# Drama,Western                     8.4
# Adventure,Drama,Sci-Fi            8.3
# Crime,Documentary                 8.3
# Fantasy                           8.2
# Biography,Documentary,Thriller    8.1
# Comedy,Crime,Documentary          8.0
# Documentary,Family                7.8
# Animation,Biography,Crime         7.8
# Name: averagerating, dtype: float64

# %%
# the ratings of the original dataframe
movie_ratings2 = df.groupby('genres')['averagerating'].mean().sort_values(ascending=False).tail(10)
movie_ratings2
# Out:
# genres
# Animation,Comedy,Crime    4.8
# Action,History            4.8
# Drama,Fantasy,Thriller    4.7
# Drama,Family,Music        4.6
# Action,Family,Fantasy     4.3
# Sci-Fi                    4.2
# Comedy,Drama,Horror       4.2
# Fantasy,Horror            3.8
# Drama,Mystery,Western     3.4
# Comedy,Thriller           2.1
# Name: averagerating, dtype: float64

# %%
# averageratings of the best_100 movies
best_100_rate= best_100_genre.groupby('genres')['averagerating'].mean().sort_values(ascending=False).head(10)
best_100_rate
# Out:
# genres
# Music        8.166667
# Sci-Fi       8.035714
# Western      8.000000
# Adventure    7.950000
# Thriller     7.938462
# Action       7.928571
# Animation    7.925000
# Biography    7.922727
# Drama        7.920968
# History      7.914286
# Name: averagerating, dtype: float64

# %%
best_rate = best_100_votes[best_100_votes['averagerating']>7].sort_values(by ='genres',ascending = False).head(100)
best_rate
# Out:
#                            title studio  domestic_gross  foreign_gross  year  \
# 26                Shutter Island   Par.     128000000.0              0  2010
# 3285                     Get Out   Uni.     176000000.0              0  2017
# 864             Django Unchained  Wein.     162800000.0              0  2012
# 1415              The Book Thief    Fox      21500000.0              0  2013
# 2345                        Room    A24      14700000.0              0  2015
# ...                          ...    ...             ...            ...   ...
# 2199                The Revenant    Fox     183600000.0              0  2015
# 1734  How to Train Your Dragon 2    Fox     177000000.0              0  2014
# 9       How to Train Your Dragon   P/DW     217600000.0              0  2010
# 3640               Incredibles 2     BV     608600000.0              0  2018
# 1733                  Big Hero 6     BV     222500000.0              0  2014
#
# ...

# %%
# create a barchart to show genres vs averagerating
genres = df_genre['genres'].head(100)
averagerating = best_rate['averagerating'].head(100)
fig = plt.figure(figsize = (10,5))
#  Bar plot
plt.bar(genres,averagerating , color ='green',
        width = 0.5)
plt.xlabel("Genres")
plt.ylabel("Averagerating")
plt.xticks(rotation= 80,fontsize=10)
plt.title("Genres and averagerating ")
plt.show();

# %%
'''
In the top 100 of the movies in terms of averagerating, most of the genres seem to have had a high rating of 5 and above, with history having the highest rating.
'''
# Out:
# '\nIn the top 100 of the movies in terms of averagerating, most of the genres seem to have had a high rating of 5 and above, with history having the highest rating.\n'

# %% [markdown]
# ## 3.6 Data analysis on genre and total gross

# %%
df['total_gross'].mean()
# Out:
# 55686436.31443639

# %%
best100_gross = best_100_votes[best_100_votes['total_gross']>109000].sort_values(by ='averagerating',ascending = False).head(100)
best100_gross
# Out:
#                                title studio  domestic_gross  foreign_gross  \
# 3                          Inception     WB     292600000.0              0
# 1732                    Interstellar   Par.     188000000.0              0
# 3637          Avengers: Infinity War     BV     678800000.0              0
# 2762                          Dangal    UTV      12400000.0              0
# 1848                        Whiplash    SPC      13100000.0              0
# ...                              ...    ...             ...            ...
# 2286                         Sicario    LGF      46900000.0              0
# 1730  Dawn of the Planet of the Apes    Fox     208500000.0              0
# 1415                  The Book Thief    Fox      21500000.0              0
# 462                        Moneyball   Sony      75600000.0              0
# 3667                   A Quiet Place   Par.     188000000.0              0
#
# ...

# %%
best100_gross = best100_gross.assign(genres= best100_gross['genres'].str.split(","))
best100_gross.head()
# Out:
#                        title studio  domestic_gross  foreign_gross  year  \
# 3                  Inception     WB     292600000.0              0  2010
# 1732            Interstellar   Par.     188000000.0              0  2014
# 3637  Avengers: Infinity War     BV     678800000.0              0  2018
# 2762                  Dangal    UTV      12400000.0              0  2016
# 1848                Whiplash    SPC      13100000.0              0  2014
#
#               original_title  start_year  runtime_minutes  \
# 3                  Inception      2010.0            148.0
# 1732            Interstellar      2014.0            169.0
# 3637  Avengers: Infinity War      2018.0            149.0
# 2762                  Dangal      2016.0            161.0
# 1848                Whiplash      2014.0            106.0
#
#                            genres  averagerating   numvotes  total_gross
# 3     [Action, Adventure, Sci-Fi]            8.8  1841066.0  292600000.0
# ...

# %%
best100_gross = best100_gross.explode('genres').head(100)
best100_gross
# Out:
#                                 title studio  domestic_gross  foreign_gross  \
# 3                           Inception     WB     292600000.0              0
# 3                           Inception     WB     292600000.0              0
# 3                           Inception     WB     292600000.0              0
# 1732                     Interstellar   Par.     188000000.0              0
# 1732                     Interstellar   Par.     188000000.0              0
# ...                               ...    ...             ...            ...
# 12                  The King's Speech  Wein.     135500000.0              0
# 1434               Dallas Buyers Club  Focus      27300000.0              0
# 1434               Dallas Buyers Club  Focus      27300000.0              0
# 981   The Perks of Being a Wallflower   LG/S      17700000.0              0
# 3284                Blade Runner 2049     WB      92100000.0              0
#
# ...

# %%
gross_mean = best100_gross.groupby(['genres']).total_gross.mean().sort_values(ascending=False).head(10)
gross_mean
# Out:
# genres
# Sci-Fi       3.082800e+08
# Animation    3.080200e+08
# Action       2.981111e+08
# Adventure    2.871929e+08
# Comedy       2.571444e+08
# Western      1.628000e+08
# Thriller     1.594500e+08
# Music        1.268667e+08
# Mystery      1.189333e+08
# Biography    9.490000e+07
# Name: total_gross, dtype: float64

# %%
# create a barchart to show genres vs total_gross
genres = best100_gross['genres'].head(100)
total_gross = best100_gross['total_gross'].head(100)
fig = plt.figure(figsize = (12, 9))
#  Bar plot
plt.bar(genres,total_gross , color ='green',
        width = 0.5)
plt.xlabel("Genres")
plt.ylabel("Total_gross")
plt.xticks(rotation= 80,fontsize=10)
plt.title("Genres vs total_gross ")
plt.show();

# %%
'''
The genres that made the most gross earnings from both the foreign_gross and domestic_gross were action,scifi and adventure in regards to the top 100.
'''
# Out:
# '\nThe genres that made the most gross earnings from both the foreign_gross and domestic_gross were action,scifi and adventure in regards to the top 100.\n'

# %% [markdown]
# ## 3.7 Data analysis on genre and year

# %%
#combine the start year and year into a single column year
#combine_first replaces missing values in column with values in column 2 and vice versa
best_100_votes["year"] = df["start_year"].combine_first(df["year"])

# %%
# drop rows with values missing in both start_year and year columns
df_year = df.drop(["start_year", "year"], 1, inplace=True)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp/ipykernel_18844/638074387.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df_year = df.drop(["start_year", "year"], 1, inplace=True)

# %%
genre_count= best100_gross['genres'].value_counts()
genre_count
# Out:
# Drama        25
# Adventure    14
# Biography    11
# Action        9
# Comedy        9
# Thriller      6
# Sci-Fi        5
# Animation     5
# Crime         5
# Music         3
# History       3
# Mystery       3
# Western       1
# Sport         1
# Name: genres, dtype: int64

# %%
# create a barplot to show the total_gross over the years 
genre = best100_gross['total_gross'].mean()
year = best100_gross['year']
fig = plt.figure(figsize = (10, 5))
#  Bar plot
plt.bar(year,total_gross,color ='green',
        width = 0.5)
plt.xlabel("year")
plt.ylabel("genre_count")
plt.xticks(rotation= 80,fontsize=10)
plt.title("Years vs value count for genres")
plt.show();

# %%
# plot a histogram to show the distribution of genres in the dataframe
data= best100_gross['genres'].value_counts()
plt.figure(figsize=(10,9))
plt.hist(data, bins=21, align='left', color='g', edgecolor='r',
              linewidth=1)
 
# Add axis labels
plt.xlabel("Genres")
plt.xticks(rotation= 80,fontsize=10)
plt.ylabel("Frequency")
plt.title("Distribution of genres")
 
plt.show()

# %%
'''
2018 had the highest totalgross
'''
# Out:
# '\n2018 had the highest totalgross\n'

# %%
best_100_votes['year'].value_counts()
# Out:
# 2014.0    18
# 2016.0    13
# 2012.0    11
# 2017.0    11
# 2013.0    11
# 2015.0    11
# 2010.0    10
# 2011.0     8
# 2018.0     7
# Name: year, dtype: int64

# %%
# plot a histogram to show the distribution of genres in the dataframe
data= best100_gross['year']
plt.figure(figsize=(10,9))
plt.hist(data, bins=21, align='left', color='g', edgecolor='r',
              linewidth=1)
 
# Add axis labels
plt.xlabel("Year")
plt.xticks(rotation= 80,fontsize=10)
plt.ylabel("Year_count")
plt.title("Distribution of genres")
 
plt.show()

# %%
'''
Most movies were produced in the year 2014 and 2016
'''
# Out:
# '\nMost movies were produced in the year 2014 and 2016\n'

# %% [markdown]
# ## 3.8 Final analysis

# %%
'''
The rating of the movies does not necessarily influence the number of movie that are produced for each genre.For example from the top_100 comedy has a low rating yet the production is high.
Some high ratings also had a few number of votes for example the highest rating of 9.2 had 8 votes, this can be because the number of people that watch those genres of movies are not many in number.
The rating when the genres are combined is different from when the rating is done on each genre individually

'''
# Out:
# '\nThe rating of the movies does not necessarily influence the number of movie that are produced for each genre.For example from the top_100 comedy has a low rating yet the production is high.\nSome high ratings also had a few number of votes for example the highest rating of 9.2 had 8 votes, this can be because the number of people that watch those genres of movies are not many in number.\nThe rating when the genres are combined is different from when the rating is done on each genre individually\n\n'
